# %%
n = 5
ans = 1
while(n > 0):
    ans *= n
    print(ans)
    n -= 1
# Out:
# 5
# 20
# 60
# 120
# 120

# %%
s=0
while s<=300:
    i=int(input('enter the no'))
    s=s+i
print("sum", s)
# Out:
# enter the no 2
# enter the no 5
# enter the no 299
# sum 306

# %%
s=0

while s<=300:
    i = int(input('enter the no'))
    s=i+1
    if i==0:
        print("sum exceeded 300")
        break
print("final sum=", i)
# Out:
# enter the no 1
# enter the no 6
# enter the no 9
# enter the no 7
# enter the no 301
# final sum= 301

# %%
while True:
    x = input("enter a string: ")
    if(x=="bon"):
        print("Voyage")
        break
# Out:
# enter a string:  bon
# Voyage

# %%
l = ['b','y','e']
l[1] = 'e'
print(l)
# Out:
# ['b', 'e', 'e']

# %%
l = ['b','y','e']
l = l+['e']
print(l)
# Out:
# ['b', 'y', 'e', 'e']

# %%
l = ['b','y','e','e']
l.append('y')
print(l)
# Out:
# ['b', 'y', 'e', 'e', 'y']

# %%
list = [2,7,8,6,9,3]
list.sort()
print(list)
# Out:
# [2, 3, 6, 7, 8, 9]
